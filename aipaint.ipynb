# %% [markdown]
# ## **安装stable-diffusion-webui**

# %%
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui
# %cd /content/stable-diffusion-webui/extensions
# !wget https://huggingface.co/SakerLy/chilloutmix_NiPrunedFp32Fix/resolve/main/chilloutmix_NiPrunedFp32Fix.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/chilloutmix_NiPrunedFp32Fix.safetensors
# !wget https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors -O /content/stable-diffusion-webui/models/VAE/vae-ft-mse-840000-ema-pruned.safetensorsvae-ft-mse-840000-ema-pruned.safetensors

# %% [markdown]
# # **启动webui**

# %%
# %cd /content/stable-diffusion-webui
# !python launch.py --share --xformers --enable-insecure-extension-access

# %% [markdown]
# 在命令执行输出里面找到public url公网访问地址，点击进入webui
#
# 为了使生成的人物更真实，可以使用Lora模型，在使用前需要配置，在Extensions里面找到Available，里面有URL地址，这个地址保持默认即可，直接点击Load From,在出现的列表中搜索lora，install这个插件【Kohya-ss Additional Networks】
# ![image.png](data:image/png;base64,...)
# 然后返回到Settings里面进行Reload UI，刷新页面。重启完成后回到txt2image页面，这时候就出现了Additional Networks了，展开可以看到model1~model5下拉框

# %% [markdown]
# # **安装模型**

# %% [markdown]
# 运行此命令需要先暂停webui的运行，等模型下载完毕，再重新运行webui的命令（各个cell的命令行不能并行运行）
#
# 下载Lora模型，可以去civitai：https://civitai.com/
# 或者huggingface：https://huggingface.co/models 下载，存储路径固定，下载链接以及下载后模型的名字根据需要更改

# %%
#!wget https://civitai.com/api/download/models/11523 -O /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/RealisticGenshin.safetensors
#!wget https://civitai.com/api/download/models/22968 -O /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/koreanDollLikenesss.safetensors
#!wget https://civitai.com/api/download/models/16557 -O /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/ShojoVibe.safetensors
#!wget https://civitai.com/api/download/models/18242 -O /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/mimi.safetensors
# !wget https://civitai.com/api/download/models/17518 -O /content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora/guofeng3.safetensors

# %% [markdown]
# 下载checkpoint，同操作

# %%
#!wget https://civitai.com/api/download/models/15236 -O /content/stable-diffusion-webui/models/Stable-diffusion/Deliberate.safetensors
# !wget https://civitai.com/api/download/models/7552 -O /content/stable-diffusion-webui/models/Stable-diffusion/HARDblend.safetensors
#!wget https://civitai.com/api/download/models/13671 -O /content/stable-diffusion-webui/models/Stable-diffusion/WoopWoop-Photo.safetensors
#!wget https://civitai.com/api/download/models/19597 -O /content/stable-diffusion-webui/models/Stable-diffusion/BeautyProMix.safetensors
#!wget https://civitai.com/api/download/models/11745 -O /content/stable-diffusion-webui/models/Stable-diffusion/ChilloutMix.safetensors
#!wget https://civitai.com/api/download/models/17414 -O /content/stable-diffusion-webui/models/Stable-diffusion/GuoFeng3.safetensors

# %% [markdown]
# 找到Additional Networks，点击enable启用模型，再model1～model5下拉框选择需要的模型，调整权重
#
# 在左上角找到checkpoint的下拉框选择需要的checkpoint
#
# checkpoint和lora可以同时使用也可以单独使用，非必须组合使用
#
# 自己写图片描述或者去civitai下载，在civitai上的图片右下角叹号处一般都会提供Prompt，可以看到Prompt、Negative prompt，直接Copy到本地stable-diffusion-webui里就行
#
# 点击Generate静待片刻，图片就生成了

# %% [markdown]
# # **参数设置**
# Batch count ：同样的配置，循环跑几次
#
# Batch size ：每批数量
#
# 同时生成多少个图像。增加这个值可以并行运行，但也需要更多的显存。
#
# ***采样方法 Sampling method***
#
# 1.Euler a ：富有创造力，不同步数可以生产出不同的图片。 超过30~40步基本就没什么增益了。
#
# 2.Euler：最最常见基础的算法，最简单的，也是最快的。
#
# 3.DDIM：收敛快，一般20步就差不多了。
#
# 4.LMS：eular的延伸算法，相对更稳定一点，30步就比较稳定了
#
# 5.PLMS：再改进一点LMS
#
# 6.DPM2：DDIM的一种改进版，它的速度大约是 DDIM 的两倍
#
# ***提示词相关性 CFG Scale***
#
# 增加这个值将导致图像更接近你的提示,但过高会让图像色彩过于饱和（你可以自己试试看）
# 太高后在一定程度上降低了图像质量。可以适当增加采样步骤来抵消画质的劣化。
# 一般在5~15之间为好，7，9，12是3个常见的设置值。

# %% [markdown]
# 询问chatgpt，让他给prompt的示例
#
# Examples of high quality prompt for stunning close-up photorealistic illustration of Ana de Armas for text-to-image models (Stable Diffusion, midjourney or Dalle2) are portrait of beautiful happy young ana de armas, ethereal, realistic anime, trending on pixiv, detailed, clean lines, sharp lines, crisp lines, award winning illustration, masterpiece, 4k, eugene de blaas and ross tran, vibrant color scheme, intricately detailed alberto seveso and geo2099 style, A highly detailed and hyper realistic portrait of a gorgeous young ana de armas, lisa frank, trending on artstation, butterflies, floral, sharp focus, studio photo, intricate details, highly detailed, by Tvera and wlop and artgerm Give me more examples.
